# %%
# from https://keras.io/examples/audio/wav2vec2_audiocls/

# %%
from datasets import load_dataset

speech_commands_v1 = load_dataset("superb", "ks")
# Out:
# /home/adam/tftest/.venv/lib/python3.10/site-packages/datasets/load.py:1486: FutureWarning: The repository for superb contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/superb
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# ...
# Generating test split:   0%|          | 0/3081 [00:00<?, ? examples/s]

# %%
type(speech_commands_v1['train'])
# Out:
# datasets.arrow_dataset.Dataset

# %%
speech_commands_v1['train']['audio']
# Out:
# [{'path': '/home/adam/.cache/huggingface/datasets/downloads/extracted/4337bad47d93b344166f6ea422a71b3b61a51173c94f6d95864321e4000caf77/_background_noise_/doing_the_dishes.wav',
#   'array': array([ 0.        ,  0.        ,  0.        , ..., -0.00592041,
#          -0.00405884, -0.00253296]),
#   'sampling_rate': 16000},
#  {'path': '/home/adam/.cache/huggingface/datasets/downloads/extracted/4337bad47d93b344166f6ea422a71b3b61a51173c94f6d95864321e4000caf77/_background_noise_/dude_miaowing.wav',
#   'array': array([ 0.        ,  0.        ,  0.        , ...,  0.00289917,
#           0.00338745, -0.00033569]),
#   'sampling_rate': 16000},
#  {'path': '/home/adam/.cache/huggingface/datasets/downloads/extracted/4337bad47d93b344166f6ea422a71b3b61a51173c94f6d95864321e4000caf77/_background_noise_/exercise_bike.wav',
#   'array': array([ 0.        ,  0.        ,  0.        , ..., -0.02764893,
#          -0.01760864,  0.00912476]),
#   'sampling_rate': 16000},
# ...
